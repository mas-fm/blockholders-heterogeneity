# %%
import pandas as pd
import numpy as np
from pandasql import sqldf

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
df = pd.read_excel (r'D:\User\Desktop\thesis\data\blockholders\main data\firm\statements_variables2.xlsx')
dd = pd.read_excel (r'D:\User\Desktop\thesis\data\blockholders\main data\firm\firm_charactristic4.xlsx')

# %%
df.rename(columns={"firm": "Ticker"}, inplace = True)
df.rename(columns={"year": "Year"}, inplace = True)
dd.rename(columns={"Mean_marketcap": "Marketcap"}, inplace = True)

# %%
df
# Out:
#      Ticker  Year    sales  net_income  fixed_asset  total_asset  total_debt  \
# 0     آ س پ  1390   451559      180220        34111       573994      185683
# 1     آ س پ  1391   519463      201009        40459       769359      390377
# 2     آ س پ  1392   504561      170395        35980      1192428      818995
# 3     آ س پ  1393   392646      141262        32894      1220730      637919
# 4     آ س پ  1394   323812      112268        38543      1447582      432519
# ...     ...   ...      ...         ...          ...          ...         ...
# 5889    غگل  1396  2277401      332839       896617      1923648     1434986
# 5890    غگل  1397  2659481      162323      1114900      2012734     1629762
# 5891    غگل  1398  3957447      598269      1237445      2306257     1498451
# 5892    غگل  1399  6153087      557169      7802907      9460226     2718427
# 5893    غگل  1400  9357027     2147964      6955681     11590192     3127907
#
#           CEQ      FCF   capex       ROA  Sales_Growth  Firm_Size  \
# 0      388311    46876  -13004  0.313975    137.072446   5.758907
# 1      378982    81208   -5077  0.261268     15.037681   5.886129
# 2      373433    93339   -1993  0.142898     -2.868732   6.076432
# 3      582811   -78244   11019  0.115719    -22.180668   6.086620
# 4     1015063  -214916  -10464  0.077556    -17.530804   6.160643
# ...       ...      ...     ...       ...           ...        ...
# 5889   488662   461415 -112200  0.173025     19.380036   6.284126
# 5890   382972   509963 -149504  0.080648     16.777019   6.303786
# 5891   807806   755496 -109725  0.259411     48.805237   6.362908
# 5892  6741799  1707942 -566576  0.058896     55.481223   6.975902
# 5893  8462285  2781920 -740451  0.185326     52.070449   7.064091
#
#       Fixed_Assets  Capital_Expenditures  Leverage  Amihud_Illiquidity
# 0         0.059427             -0.022655  0.323493       -2.961102e-08
# 1         0.052588             -0.006599  0.507406        3.044605e-05
# 2         0.030174             -0.001671  0.686830       -9.627671e-07
# 3         0.026946              0.009027  0.522572       -8.875830e-06
# 4         0.026626             -0.007229  0.298787       -1.185162e-05
# ...            ...                   ...       ...                 ...
# 5889      0.466102             -0.058327  0.745971       -1.633095e-03
# 5890      0.553923             -0.074279  0.809725        2.590406e-04
# 5891      0.536560             -0.047577  0.649733        7.416335e-07
# 5892      0.824812             -0.059890  0.287353       -1.739344e-07
# 5893      0.600135             -0.063886  0.269875       -1.267860e-07
#
# [5894 rows x 17 columns]

# %%
dd
# Out:
#        firm                      group_name  year  Mean_marketcap  \
# 0     آ س پ     انبوه سازی، املاک و مستغلات  1390    7.104690e+11
# 1     آ س پ     انبوه سازی، املاک و مستغلات  1391    7.445939e+11
# 2     آ س پ     انبوه سازی، املاک و مستغلات  1392    7.914647e+11
# 3     آ س پ     انبوه سازی، املاک و مستغلات  1393    1.259606e+12
# 4     آ س پ     انبوه سازی، املاک و مستغلات  1394    9.975240e+11
# ...     ...                             ...   ...             ...
# 6669   گکیش                   هتل و رستوران  1400    8.181235e+12
# 6670   یارا  صندوق سرمایه گذاری قابل معامله  1400    1.000000e+12
# 6671  یاقوت  صندوق سرمایه گذاری قابل معامله  1398    5.000000e+12
# 6672  یاقوت  صندوق سرمایه گذاری قابل معامله  1399    2.239545e+13
# 6673  یاقوت  صندوق سرمایه گذاری قابل معامله  1400    5.219402e+13
#
#       total_percent_ownership  institutional_percent_ownership  Holder_Number  \
# 0                       91.53                            91.53              7
# 1                       91.80                            91.80             12
# 2                       92.57                            90.81             14
# 3                       91.26                            90.19              7
# 4                       90.59                            90.59              6
# ...                       ...                              ...            ...
# 6669                    59.92                             2.59              3
# 6670                    20.20                            18.70              7
# 6671                    18.37                            18.37              5
# 6672                    89.84                            82.99             17
# 6673                    64.32                            64.32              7
#
#       Number_of_Institutional_Blocks  type_Number  \
# 0                                  7            3
# 1                                 12            5
# 2                                 13            5
# 3                                  6            4
# 4                                  6            3
# ...                              ...          ...
# 6669                               2            2
# 6670                               6            3
# 6671                               5            2
# 6672                              16            6
# 6673                               7            4
#
#       type_of_Institutional_Blocks  Diversity_identity  Diversity_size  \
# 0                                3            0.160238        0.234243
# 1                                5            0.330945        0.305213
# 2                                4            0.393827        0.371337
# 3                                3            0.295098        0.275603
# 4                                3            0.283668        0.286540
# ...                            ...                 ...             ...
# 6669                             1            0.082712        0.082712
# 6670                             2            0.301196        0.746005
# 6671                             2            0.199128        0.497685
# 6672                             5            0.728253        0.428611
# 6673                             4            0.427098        0.232462
#
#       Diversity_horizon  Diversity_Index
# 0              0.161412        -0.233718
# 1              0.563205         0.112739
# 2              0.103154        -0.029473
# 3              0.023175        -0.188442
# 4              0.030217        -0.186056
# ...                 ...              ...
# 6669           0.082712        -0.411043
# 6670           0.329379         0.239389
# 6671           0.652217         0.182975
# 6672           0.378712         0.354489
# 6673           0.237765        -0.024442
#
# [6674 rows x 14 columns]

# %%
q = '''
SELECT *
FROM dd,df
WHERE dd.firm = df.Ticker AND dd.year = df.Year 
'''
names = (pysqldf(q))
names
# Out:
#        firm                   group_name  year     Marketcap  \
# 0     آ س پ  انبوه سازی، املاک و مستغلات  1390  7.104690e+11
# 1     آ س پ  انبوه سازی، املاک و مستغلات  1391  7.445939e+11
# 2     آ س پ  انبوه سازی، املاک و مستغلات  1392  7.914647e+11
# 3     آ س پ  انبوه سازی، املاک و مستغلات  1393  1.259606e+12
# 4     آ س پ  انبوه سازی، املاک و مستغلات  1394  9.975240e+11
# ...     ...                          ...   ...           ...
# 4474   گکیش                هتل و رستوران  1396  2.107384e+11
# 4475   گکیش                هتل و رستوران  1397  3.835634e+11
# 4476   گکیش                هتل و رستوران  1398  9.516545e+11
# 4477   گکیش                هتل و رستوران  1399  7.263896e+12
# 4478   گکیش                هتل و رستوران  1400  8.181235e+12
#
#       total_percent_ownership  institutional_percent_ownership  Holder_Number  \
# 0                       91.53                            91.53              7
# 1                       91.80                            91.80             12
# 2                       92.57                            90.81             14
# 3                       91.26                            90.19              7
# 4                       90.59                            90.59              6
# ...                       ...                              ...            ...
# 4474                    71.70                             0.00              1
# 4475                    76.31                             0.00              1
# 4476                    74.66                             2.01              2
# 4477                    63.34                             1.05              2
# 4478                    59.92                             2.59              3
#
#       Number_of_Institutional_Blocks  type_Number  \
# 0                                  7            3
# 1                                 12            5
# 2                                 13            5
# 3                                  6            4
# 4                                  6            3
# ...                              ...          ...
# 4474                               0            1
# 4475                               0            1
# 4476                               1            2
# 4477                               1            2
# 4478                               2            2
#
#       type_of_Institutional_Blocks  ...      CEQ     FCF   capex       ROA  \
# 0                                3  ...   388311   46876  -13004  0.313975
# 1                                5  ...   378982   81208   -5077  0.261268
# 2                                4  ...   373433   93339   -1993  0.142898
# 3                                3  ...   582811  -78244   11019  0.115719
# 4                                3  ...  1015063 -214916  -10464  0.077556
# ...                            ...  ...      ...     ...     ...       ...
# 4474                             0  ...    63304    5629   -9800  0.074690
# 4475                             0  ...    81410    8745  -22148  0.086908
# 4476                             1  ...    88529   10821  -12621  0.117102
# 4477                             1  ...   221973   37596  -33872  0.315892
# 4478                             1  ...   284864   17938 -115529  0.046669
#
#      Sales_Growth  Firm_Size  Fixed_Assets  Capital_Expenditures  Leverage  \
# 0      137.072446   5.758907      0.059427             -0.022655  0.323493
# 1       15.037681   5.886129      0.052588             -0.006599  0.507406
# 2       -2.868732   6.076432      0.030174             -0.001671  0.686830
# 3      -22.180668   6.086620      0.026946              0.009027  0.522572
# 4      -17.530804   6.160643      0.026626             -0.007229  0.298787
# ...           ...        ...           ...                   ...       ...
# 4474    13.684606   4.833453      0.713814             -0.143805  0.071081
# 4475    10.789822   4.940382      0.579858             -0.254069  0.066110
# 4476     6.957494   4.995854      0.536123             -0.127420  0.106219
# 4477   -15.366381   5.448111      0.745256             -0.120706  0.208977
# 4478    67.130736   5.588432      0.632951             -0.298029  0.265138
#
#       Amihud_Illiquidity
# 0          -2.961102e-08
# 1           3.044605e-05
# 2          -9.627671e-07
# 3          -8.875830e-06
# 4          -1.185162e-05
# ...                  ...
# 4474        5.060256e-05
# 4475        1.949559e-06
# 4476        1.446273e-06
# 4477       -2.232351e-05
# 4478        6.479154e-05
#
# [4479 rows x 31 columns]

# %%
names.drop(['Ticker','Year'], axis=1 , inplace = True)
names
# Out:
#        firm                   group_name  year     Marketcap  \
# 0     آ س پ  انبوه سازی، املاک و مستغلات  1390  7.104690e+11
# 1     آ س پ  انبوه سازی، املاک و مستغلات  1391  7.445939e+11
# 2     آ س پ  انبوه سازی، املاک و مستغلات  1392  7.914647e+11
# 3     آ س پ  انبوه سازی، املاک و مستغلات  1393  1.259606e+12
# 4     آ س پ  انبوه سازی، املاک و مستغلات  1394  9.975240e+11
# ...     ...                          ...   ...           ...
# 4474   گکیش                هتل و رستوران  1396  2.107384e+11
# 4475   گکیش                هتل و رستوران  1397  3.835634e+11
# 4476   گکیش                هتل و رستوران  1398  9.516545e+11
# 4477   گکیش                هتل و رستوران  1399  7.263896e+12
# 4478   گکیش                هتل و رستوران  1400  8.181235e+12
#
#       total_percent_ownership  institutional_percent_ownership  Holder_Number  \
# 0                       91.53                            91.53              7
# 1                       91.80                            91.80             12
# 2                       92.57                            90.81             14
# 3                       91.26                            90.19              7
# 4                       90.59                            90.59              6
# ...                       ...                              ...            ...
# 4474                    71.70                             0.00              1
# 4475                    76.31                             0.00              1
# 4476                    74.66                             2.01              2
# 4477                    63.34                             1.05              2
# 4478                    59.92                             2.59              3
#
#       Number_of_Institutional_Blocks  type_Number  \
# 0                                  7            3
# 1                                 12            5
# 2                                 13            5
# 3                                  6            4
# 4                                  6            3
# ...                              ...          ...
# 4474                               0            1
# 4475                               0            1
# 4476                               1            2
# 4477                               1            2
# 4478                               2            2
#
#       type_of_Institutional_Blocks  ...      CEQ     FCF   capex       ROA  \
# 0                                3  ...   388311   46876  -13004  0.313975
# 1                                5  ...   378982   81208   -5077  0.261268
# 2                                4  ...   373433   93339   -1993  0.142898
# 3                                3  ...   582811  -78244   11019  0.115719
# 4                                3  ...  1015063 -214916  -10464  0.077556
# ...                            ...  ...      ...     ...     ...       ...
# 4474                             0  ...    63304    5629   -9800  0.074690
# 4475                             0  ...    81410    8745  -22148  0.086908
# 4476                             1  ...    88529   10821  -12621  0.117102
# 4477                             1  ...   221973   37596  -33872  0.315892
# 4478                             1  ...   284864   17938 -115529  0.046669
#
#       Sales_Growth  Firm_Size  Fixed_Assets  Capital_Expenditures  Leverage  \
# 0       137.072446   5.758907      0.059427             -0.022655  0.323493
# 1        15.037681   5.886129      0.052588             -0.006599  0.507406
# 2        -2.868732   6.076432      0.030174             -0.001671  0.686830
# 3       -22.180668   6.086620      0.026946              0.009027  0.522572
# 4       -17.530804   6.160643      0.026626             -0.007229  0.298787
# ...            ...        ...           ...                   ...       ...
# 4474     13.684606   4.833453      0.713814             -0.143805  0.071081
# 4475     10.789822   4.940382      0.579858             -0.254069  0.066110
# 4476      6.957494   4.995854      0.536123             -0.127420  0.106219
# 4477    -15.366381   5.448111      0.745256             -0.120706  0.208977
# 4478     67.130736   5.588432      0.632951             -0.298029  0.265138
#
#       Amihud_Illiquidity
# 0          -2.961102e-08
# 1           3.044605e-05
# 2          -9.627671e-07
# 3          -8.875830e-06
# 4          -1.185162e-05
# ...                  ...
# 4474        5.060256e-05
# 4475        1.949559e-06
# 4476        1.446273e-06
# 4477       -2.232351e-05
# 4478        6.479154e-05
#
# [4479 rows x 29 columns]

# %%
names.to_excel (r'D:\User\Desktop\thesis\data\blockholders\main data\firm\final_merg.xlsx',index=False)
