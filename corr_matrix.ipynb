# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'D:\User\Desktop\thesis\data\blockholders\main data\firm\final_dataa(t).xlsx')

# %%
df.drop(["year", "sales","net_income", "fixed_asset","total_asset", "total_debt","CEQ", "capex",'stock_id','group_id','Marketcap','Number_of_Institutional_Blocks','type_of_Institutional_Blocks','Holder_Number','type_Number'], axis = 1, inplace = True)

# %%
list(df)
# Out:
# ['firm',
#  'group_name',
#  'total_percent_ownership',
#  'institutional_percent_ownership',
#  'Diversity_identity',
#  'Diversity_size',
#  'Diversity_horizon',
#  'Diversity_Index',
#  'FCF',
#  'ROA',
#  'Sales_Growth',
#  'Firm_Size',
#  'Fixed_Assets',
#  'Capital_Expenditures',
#  'Leverage',
#  'Amihud_Illiquidity',
#  'Tobins_Q',
#  'Tobins_Q_(t+1)',
#  'ROA_(t+1)',
#  'FCF_(t+1)',
#  'Tobins_Q_(t+2)',
#  'ROA_(t+2)',
#  'FCF_(t+2)',
#  'Tobins_Q_(t+3)',
#  'ROA_(t+3)',
#  'FCF_(t+3)']

# %%
df = df[['Diversity_identity', 'Diversity_size', 'Diversity_horizon', 'Diversity_Index','total_percent_ownership','institutional_percent_ownership','Tobins_Q','Tobins_Q_(t+1)',
'ROA', 'ROA_(t+1)', 'FCF', 'FCF_(t+1)','Sales_Growth','Firm_Size','Fixed_Assets','Capital_Expenditures','Leverage','Amihud_Illiquidity']]

# %%
corrM = df.corr().round(3)
corrM
# Out:
#                                  Diversity_identity  Diversity_size  \
# Diversity_identity                            1.000           0.585
# Diversity_size                                0.585           1.000
# Diversity_horizon                             0.560           0.497
# Diversity_Index                               0.869           0.834
# total_percent_ownership                      -0.096          -0.053
# institutional_percent_ownership              -0.066          -0.003
# Tobins_Q                                     -0.002          -0.027
# Tobins_Q_(t+1)                                0.007          -0.009
# ROA                                          -0.007          -0.008
# ROA_(t+1)                                     0.005           0.006
# FCF                                           0.012           0.026
# FCF_(t+1)                                    -0.004           0.019
# Sales_Growth                                 -0.011          -0.031
# ...

# %%
corrM.to_excel (r'corr_matrix2.xlsx')
